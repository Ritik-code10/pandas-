# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritik-code10/pandas-/blob/main/Pandas_Class5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as pd
data = {
    'Product' : ['Pen','Notebook','Pencil','Marker','Eraser','shrapner'],
    'Price' : [10,50,5,30,8,12],
    'Stock' : [100,60,200,80,150,120],
    'Rating' : [4.5,4.7,4.2,4.8,4.3,4.4]
}

df = pd.DataFrame(data)
df

#1. sort  by a single column -> price , ascending
print(df.sort_values(by = 'Price'))

#2. sort  by a single column -> price , Descending
print(df.sort_values(by = 'Rating',ascending=False))

#3. sort by Multiple columns -> Price and stock
df.sort_values(by = ['Price','Stock'])

#4. sort by index -> in descending order.
print(df.sort_index(ascending=False))
# Out:
#     Product  Price  Stock  Rating
# 2    Pencil      5    200     4.2
# 4    Eraser      8    150     4.3
# 0       Pen     10    100     4.5
# 5  shrapner     12    120     4.4
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
#     Product  Price  Stock  Rating
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5
# 5  shrapner     12    120     4.4
# 4    Eraser      8    150     4.3
# 2    Pencil      5    200     4.2
#     Product  Price  Stock  Rating
# 5  shrapner     12    120     4.4
# 4    Eraser      8    150     4.3
# 3    Marker     30     80     4.8
# 2    Pencil      5    200     4.2
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
print(df)

#1. Meam of numeric columns only
df.mean(numeric_only=True)

#2. Median
df.median(numeric_only=True)

#3. mode
print(df.mode())

#4. std
print(df.std(numeric_only=True))

#5. complete describe
print(df.describe())
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 1  Notebook     50     60     4.7
# 2    Pencil      5    200     4.2
# 3    Marker     30     80     4.8
# 4    Eraser      8    150     4.3
# 5  shrapner     12    120     4.4
#     Product  Price  Stock  Rating
# 0    Eraser      5     60     4.2
# 1    Marker      8     80     4.3
# 2  Notebook     10    100     4.4
# 3       Pen     12    120     4.5
# 4    Pencil     30    150     4.7
# 5  shrapner     50    200     4.8
# Price     17.486185
# Stock     50.760877
# Rating     0.231661
# dtype: float64
#            Price       Stock    Rating
# count   6.000000    6.000000  6.000000
# mean   19.166667  118.333333  4.483333
# std    17.486185   50.760877  0.231661
# min     5.000000   60.000000  4.200000
# 25%     8.500000   85.000000  4.325000
# 50%    11.000000  110.000000  4.450000
# 75%    25.500000  142.500000  4.650000
# max    50.000000  200.000000  4.800000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
print(df)

#1. Count how many times each product appears
print(df['Product'].value_counts())

#2. Count how many times each product appears in percentage/show percentage instead of counts
print(df['Product'].value_counts(normalize=True))

#3. Count values for column Rating
print(df['Rating'].value_counts())
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 1  Notebook     50     60     4.7
# 2    Pencil      5    200     4.2
# 3    Marker     30     80     4.8
# 4    Eraser      8    150     4.3
# 5  shrapner     12    120     4.4
# Product
# Pen         1
# Notebook    1
# Pencil      1
# Marker      1
# Eraser      1
# shrapner    1
# Name: count, dtype: int64
# Product
# Pen         0.166667
# Notebook    0.166667
# Pencil      0.166667
# Marker      0.166667
# Eraser      0.166667
# shrapner    0.166667
# Name: proportion, dtype: float64
# Rating
# 4.5    1
# 4.7    1
# 4.2    1
# 4.8    1
# 4.3    1
# 4.4    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
#1. Correlation between all numeric column
print(df.corr(numeric_only=True))
# -ve correlation -> one increases 2nd decrease
# +ve correlation -> one increases other increse
#2. Covariance between all numeric column
print(df.cov(numeric_only=True))

#3. correlation between 2 specific column.
print(df['Price'].corr(df['Stock']))
# Out:
#            Price     Stock    Rating
# Price   1.000000 -0.804028  0.820402
# Stock  -0.804028  1.000000 -0.921257
# Rating  0.820402 -0.921257  1.000000
#              Price        Stock     Rating
# Price   305.766667  -713.666667   3.323333
# Stock  -713.666667  2576.666667 -10.833333
# Rating    3.323333   -10.833333   0.053667
# np.float64(-0.8040280933316356)

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height
import pandas as pd
df = pd.DataFrame({
    "Name" : ['Rahul','Aman','Yash','Amit','Ayushi'],
    "Age" : [29,22,32,20,21],
    "Score" : [65,84,56,75,90],
    "Height" : [5.9,6.2,6.9,5.5,5.8]
})


# 2. Sort the data by Score (descending)
# Write your code here
print(df.sort_values(by = "Score" , ascending=False))


# 3. Get mean, median, mode, and std of numeric columns
# Write your code here
print(df.mean(numeric_only=True))
print(df.median(numeric_only=True))
print(df.mode())
print(df.std(numeric_only=True))
# 4. Use value_counts on Name or any categorical column
# Write your code here

# 5. Compute corr() and cov() for all numeric columns
# Write your code here
# Out:
#      Name  Age  Score  Height
# 4  Ayushi   21     90     5.8
# 1    Aman   22     84     6.2
# 3    Amit   20     75     5.5
# 0   Rahul   29     65     5.9
# 2    Yash   32     56     6.9
# Age       24.80
# Score     74.00
# Height     6.06
# dtype: float64
# Age       22.0
# Score     75.0
# Height     5.9
# dtype: float64
#      Name  Age  Score  Height
# 0    Aman   20     56     5.5
# 1    Amit   21     65     5.8
# 2  Ayushi   22     75     5.9
# 3   Rahul   29     84     6.2
# 4    Yash   32     90     6.9
# Age        5.357238
# Score     13.802174
# Height     0.531977
# dtype: float64

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
